# %% [markdown]
# # Intro to Panel Data – Week 1
#
# This notebook introduces a basic panel data structure using pandas.

# %%
import pandas as pd

df = pd.read_csv('../examples/panel_structure.csv')
df.head()
